# %% [markdown]
# <a href="https://colab.research.google.com/github/sarelWeinberger/Submarine/blob/master/retrieve_data_from_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fb_json = {
  "type": "service_account",
  "project_id": "lemin-poc-db",
  "private_key_id": "bd3e61ff1733d03d50779a853d30018d08e61485",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "firebase-adminsdk-ohc8u@lemin-poc-db.iam.gserviceaccount.com",
  "client_id": "103663167132096689553",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/firebase-adminsdk-ohc8u%40lemin-poc-db.iam.gserviceaccount.com"
}

# %%
import firebase_admin
import firebase_admin.firestore
cred = firebase_admin.credentials.Certificate(fb_json)
firebase_admin.initialize_app(cred)
db = firebase_admin.firestore.client()

# %%
import pandas as pd
df = pd.DataFrame(columns=['user','title','type', 'answer' , 'summary','sourc','idx'])

for entry in db.collection('live-summary').stream():
  summary = entry.to_dict()
  for quiz in db.collection('live-quizzes').where('summary_id', '==', entry.id).stream(): 
      quiz = quiz.to_dict()

      # print(quiz) 
      df_series = pd.Series()
      try:
#         if (summary['m_text']): # 
#          for i in range(0, len(summary['m_text'])):
        df_series = pd.Series([quiz['user'], quiz['title'], quiz['type'],quiz['answer'], summary['text'][0]['text'],summary['text'][0]['summary'] ,summary['text_id']], index=df.columns)
        df = df.append(df_series, ignore_index=True)
      except Exception as e:
            (e)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   # Remove the CWD from sys.path while we load stuff.
#                    user title type  \
# 0  sB46PmGnzIOqRP9yqc86        moq
# 1  sB46PmGnzIOqRP9yqc86        moq
# 2  sB46PmGnzIOqRP9yqc86        moq
# 3  sB46PmGnzIOqRP9yqc86        moq
# 4  X2VBibEhvKbUk6TUIMZZ        moq
# 5  hiiC3FS41khPOLeZE5BJ        moq
# 6  sB46PmGnzIOqRP9yqc86        moq
# 7  sB46PmGnzIOqRP9yqc86        moq
#
#                                               answer  \
# 0  {'options': [{'answer': '22 years 68 days', 's...
# 1  {'options': [{'answer': 'He's just too good', ...
# 2  {'from': 'text', 'error': None, 'options': [{'...
# 3  {'error': None, 'from': 'summary', 'options': ...
# 4  {'options': [{'score': 0.6925660953151619, 'co...
# 5  {'from': 'text', 'error': None, 'options': [{'...
# 6  {'options': [{'score': 0.5300068200218547, 'co...
# 7  {'from': 'text', 'options': [{'answer': 'solid...
#
#                                              summary  \
# 0  Luka Dončić Luka Dončić ( / ˈ d ɒ n tʃ ɪ tʃ / ...
# 1  Luka Dončić Luka Dončić ( / ˈ d ɒ n tʃ ɪ tʃ / ...
# 2  Luka Dončić Luka Dončić ( / ˈ d ɒ n tʃ ɪ tʃ / ...
# 3  Luka Dončić Luka Dončić ( / ˈ d ɒ n tʃ ɪ tʃ / ...
# 4  Transformers have wholly rebuilt the landscape...
# 5  Orel Babayoff@*, Onn Shehory® Bar-llan Univers...
# 6  Shira Haber and Michal Leskes* Rechargeable ba...
# 7  Shira Haber and Michal Leskes* Rechargeable ba...
#
#                                                sourc                   idx
# 0  Luka Dončić was born in Ljubljana, Slovenia, i...  h7QEAjm5ssV22bCqworK
# 1  Luka Dončić was born in Ljubljana, Slovenia, i...  h7QEAjm5ssV22bCqworK
# 2  Luka Dončić was born in Ljubljana, Slovenia, i...  h7QEAjm5ssV22bCqworK
# 3  Luka Dončić was born in Ljubljana, Slovenia, i...  h7QEAjm5ssV22bCqworK
# 4  Transformers have rebuilt the landscape of nat...  VkbVtF1OCaHGwqlCJ97N
# 5  Orel Babayoff: We present a novel model for pr...  xY5QlSjzVjLgUBhYWGof
# 6  Rechargeable battery cells are composed of two...  Mv4WepTreykSZUvKbD71
# 7  Rechargeable battery cells are composed of two...  Mv4WepTreykSZUvKbD71

# %%
df_moq = df[df['type'] == 'moq']

# %%
df_moq['answer'][1]
# Out:
# {'error': None,
#  'from': 'text',
#  'options': [{'answer': "He's just too good",
#    'context': 'He was then traded to the Dallas Mavericks in exchange for the draft rights to Trae Young and a protected future first-round pick in 2019. After the draft, Mavericks head coach Rick Carlisle said, "At one point, we thought there might be a slight chance Dončić could fall to us, but a couple of days ago it was pretty clear that there was no way that was going to happen. @SENT_BEGIN@@ANS_BEGIN@He\'s just too good@ANS_END@.@SENT_END@ We get a guy we think is franchise foundation piece." He signed his rookie contract with the Mavericks on July 9, 2018.',
#    'score': 0.5298503352745344}]}
